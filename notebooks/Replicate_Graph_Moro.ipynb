# %% [markdown]
# **Make sure to include** `import allow_local_imports` on top of every notebook in `notebooks/` dir to be able to use `lib/` modules.

# %%
# Include this on top, as the first import 
# This must always be imported first. If you are restarting the notebook
# don't forget to run this cell first!
import allow_local_imports

# %%
from lib.minority_game import MinorityGame
from lib.agents.agent import Agent, StrategyUpdatingAgent
from lib.agents.factory import AgentFactory
from lib.strategies import AlwaysOneStrategy, DefaultStrategy, FiftyFiftyStrategy
from lib.memory import UniformMemoryGenerator
from lib.plots import default_plot

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm, gamma
import seaborn as sns
from numpy.random import default_rng

# %% [markdown]
# ## N = 101

# %%
n_agents = 101 # check with David why it does not work if I do MinorityGame.n_agents
tot_omega_1 = []
tot_alpha_1 = []

for M in range (2,14):
    times, attendances, mean_A_t, vol_A_t = MinorityGame(
        n_agents=101,
        factory_dict={
            1: AgentFactory(
                Agent,
                agent_kwargs=dict(
                    strategy_clss=[DefaultStrategy,DefaultStrategy]
                ),
                memory_generator=UniformMemoryGenerator(M)
            ),
        }
    ).simulate_game(max_steps=5000)
    # in order to create the graph
    omega = np.average(vol_A_t)/n_agents
    alpha = 2**M/n_agents
    tot_omega_1.append(omega)
    tot_alpha_1.append(alpha)

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.axhline(y=1, color="k", linestyle="--")
ax.plot(tot_alpha_1, tot_omega_1, 'bo')
ax.set_xlabel("Alpha = $2^m/N$")
ax.set_ylabel("Volatility")

plt.title("Simple Minority Game with s=2, N=101")
plt.yscale('log')
plt.xscale('log')
plt.xlim([0.01,100])
plt.ylim([0.1,100])

plt.show()

# %% [markdown]
# ## N = 201

# %%
n_agents = 201 # check with David why it does not work if I do MinorityGame.n_agents
tot_omega_2 = []
tot_alpha_2 = []

for M in range (2,14):
    times, attendances, mean_A_t, vol_A_t = MinorityGame(
        n_agents=201,
        factory_dict={
            1: AgentFactory(
                Agent,
                agent_kwargs=dict(
                    strategy_clss=[DefaultStrategy,DefaultStrategy]
                ),
                memory_generator=UniformMemoryGenerator(M)
            ),
        }
    ).simulate_game(max_steps=5000)
    # in order to create the graph
    omega = np.average(vol_A_t)/n_agents
    alpha = 2**M/n_agents
    tot_omega_2.append(omega)
    tot_alpha_2.append(alpha)

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.axhline(y=1, color="k", linestyle="--")
ax.plot(tot_alpha_2, tot_omega_2, 'bo')
ax.set_xlabel("Alpha = $2^m/N$")
ax.set_ylabel("Volatility")

plt.title("Simple Minority Game with s=2, N=201")
plt.yscale('log')
plt.xscale('log')
plt.xlim([0.01,100])
plt.ylim([0.1,100])

plt.show()

# %% [markdown]
# ## N = 301

# %%
n_agents = 301 # check with David why it does not work if I do MinorityGame.n_agents
tot_omega_3 = []
tot_alpha_3 = []

for M in range (2,14):
    times, attendances, mean_A_t, vol_A_t = MinorityGame(
        n_agents=301,
        factory_dict={
            1: AgentFactory(
                Agent,
                agent_kwargs=dict(
                    strategy_clss=[DefaultStrategy,DefaultStrategy]
                ),
                memory_generator=UniformMemoryGenerator(M)
            ),
        }
    ).simulate_game(max_steps=5000)
    # in order to create the graph
    omega = np.average(vol_A_t)/n_agents
    alpha = 2**M/n_agents
    tot_omega_3.append(omega)
    tot_alpha_3.append(alpha)

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.axhline(y=1, color="k", linestyle="--")
ax.plot(tot_alpha_3, tot_omega_3, 'bo')
ax.set_xlabel("Alpha = $2^m/N$")
ax.set_ylabel("Volatility")

plt.title("Simple Minority Game with s=2, N=301")
plt.yscale('log')
plt.xscale('log')
plt.xlim([0.01,100])
plt.ylim([0.1,100])

plt.show()

# %% [markdown]
# ## N = 501

# %%
n_agents = 501 # check with David why it does not work if I do MinorityGame.n_agents
tot_omega_5 = []
tot_alpha_5 = []

for M in range (2,14):
    times, attendances, mean_A_t, vol_A_t = MinorityGame(
        n_agents=501,
        factory_dict={
            1: AgentFactory(
                Agent,
                agent_kwargs=dict(
                    strategy_clss=[DefaultStrategy,DefaultStrategy]
                ),
                memory_generator=UniformMemoryGenerator(M)
            ),
        }
    ).simulate_game(max_steps=5000)
    # in order to create the graph
    omega = np.average(vol_A_t)/n_agents
    alpha = 2**M/n_agents
    tot_omega_5.append(omega)
    tot_alpha_5.append(alpha)

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.axhline(y=1, color="k", linestyle="--")
ax.plot(tot_alpha_5, tot_omega_5, 'bo')
ax.set_xlabel("Alpha = $2^m/N$")
ax.set_ylabel("Volatility")

plt.title("Simple Minority Game with s=2, N=501")
plt.yscale('log')
plt.xscale('log')
plt.xlim([0.01,100])
plt.ylim([0.1,100])

plt.show()

# %% [markdown]
# ## N = 701

# %%
n_agents = 701 # check with David why it does not work if I do MinorityGame.n_agents
tot_omega_7 = []
tot_alpha_7 = []

for M in range (2,14):
    times, attendances, mean_A_t, vol_A_t = MinorityGame(
        n_agents=701,
        factory_dict={
            1: AgentFactory(
                Agent,
                agent_kwargs=dict(
                    strategy_clss=[DefaultStrategy,DefaultStrategy]
                ),
                memory_generator=UniformMemoryGenerator(M)
            ),
        }
    ).simulate_game(max_steps=5000)
    # in order to create the graph
    omega = np.average(vol_A_t)/n_agents
    alpha = 2**M/n_agents
    tot_omega_7.append(omega)
    tot_alpha_7.append(alpha)

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.axhline(y=1, color="k", linestyle="--")
ax.plot(tot_alpha_7, tot_omega_7, 'bo')
ax.set_xlabel("Alpha = $2^m/N$")
ax.set_ylabel("Volatility")

plt.title("Simple Minority Game with s=2, N=701")
plt.yscale('log')
plt.xscale('log')
plt.xlim([0.01,100])
plt.ylim([0.1,100])

plt.show()

# %% [markdown]
# ## Everything in one graph

# %%
# everything in one graph

fig, ax = plt.subplots(figsize=(10, 8))

ax.axhline(y=1, color="k", linestyle="--") # vol = 1 -> randomness

ax.plot(tot_alpha_1, tot_omega_1, '>r')
ax.plot(tot_alpha_2, tot_omega_2, 'bo')
ax.plot(tot_alpha_3, tot_omega_3, 'Dy')
ax.plot(tot_alpha_5, tot_omega_5, 'sc')
ax.plot(tot_alpha_7, tot_omega_7, '*g')

ax.set_xlabel("Alpha = $2^m/N$")
ax.set_ylabel("Volatility $\sigma^2/N$")
ax.legend(["randomness","N = 101","N = 201", "N = 301", "N = 501", "N = 701"])

plt.title("Volatilty as a function of alpha (MG with s=2)")
plt.yscale('log')
plt.xscale('log')
plt.xlim([0.01,100])
plt.ylim([0.1,100])

plt.show()
